# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset

df=pd.read_csv("baseball--1-.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# we can see that there are no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique().to_frame("Number of unique values")
# Out:
#      Number of unique values
# W                         24
# R                         28
# AB                        29
# H                         29
# 2B                        22
# 3B                        23
# HR                        27
# BB                        29
# SO                        29
# SB                        27
# RA                        30
# ER                        30
# ERA                       30
# CG                         9
# SHO                       12
# SV                        20
# E                         21

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
#
#
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64
#
#
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64
#
#
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64
#
#
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64
#
#
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
plt.figure(figsize=(32,10))
sns.heatmap(df.describe(),annot=True,fmt='0.1f',linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel('Figure')
plt.ylabel('Features')
plt.title("Descriptive Graph")
plt.show()

# %% [markdown]
# ### Univariate Analysis

# %%
datamap=sns.countplot(df['W'],data=df)
print(df['W'].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
datamap=sns.countplot(df['R'],data=df)
print(df['R'].value_counts())
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64

# %%
datamap=sns.countplot(df['CG'],data=df)
print(df['CG'].value_counts())
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %%
plt.figure(figsize=(20,20), facecolor='white')
plotnumber=1
for col in df.columns:
    if plotnumber<=20:
        ax=plt.subplot(10,2,plotnumber)   
        sns.countplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20), facecolor='white')
plotnumber=1
for col in df.columns:
    if plotnumber<=50:
        ax=plt.subplot(10,5,plotnumber)   
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.lineplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
# It has positive correlation

# %%
sns.lineplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.lineplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.lineplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.lineplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
plt.figure(figsize=(20,20))
p=1
for i in df.columns:
    if p<=20:    
        plt.subplot(10,4,p) 
        sns.lineplot(x=df[i],y='W',data=df,color='r')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df.columns:
    if p<=20:    
        plt.subplot(10,4,p) 
        sns.regplot(x=df[i],y='W',data=df,color='r')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df.columns:
    if p<=50:    
        plt.subplot(10,5,p) 
        sns.scatterplot(x=df[i],y='W',data=df,color='r')
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(data=df,palette='Dark2')

# %%
#Multivariate Analysis is too much data ,and is not very convinient to study

# %% [markdown]
# ## Outliers

# %%
#Checking outliers

plt.figure(figsize=(30,35))
p=1
for i in df.columns:
    if p<=20:
        plt.subplot(10,5,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %%
# we can see that R,ERA,SHO,SV,E are having some outliers

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ### Zscore

# %%
from scipy.stats import zscore
out_features=df[['R','ERA','SHO','SV','E']]
z=np.abs(zscore(out_features))  
z
# Out:
#            R       ERA       SHO        SV         E
# 0   0.619078  0.506955  0.814629  1.671607  0.461470
# 1   0.134432  0.254598  0.172800  0.249879  0.607197
# 2   0.332906  0.641347  0.320914  0.654856  1.117242
# 3   1.146419  0.053010  0.567771  0.784104  0.485758
# 4   0.013270  1.531318  0.172800  1.042600  0.607197
# 5   3.509647  0.350165  0.320914  1.171848  0.461470
# 6   1.311430  0.165003  1.802057  0.637623  0.097152
# 7   0.428681  0.209800  0.320914  0.008617  1.262970
# 8   0.765626  0.484557  0.172800  2.188598  0.048576
# 9   1.034489  0.792164  0.320914  0.396360  0.194303
# 10  1.086415  0.635374  0.567771  0.249879  1.797303
# 11  0.705622  0.865333  0.419657  0.525608  0.680061
# 12  0.471376  0.036584  0.172800  0.379127  0.097152
# 13  0.557920  0.456185  0.172800  0.249879  0.024288
# 14  0.099814  0.411388  0.913371  1.947335  2.307348
# 15  0.713699  2.276445  0.913371  2.447094  0.121439
# 16  0.151740  1.671683  0.419657  1.413111  2.015894
# 17  0.013270  1.335704  2.394514  0.637623  1.214394
# 18  0.575229  0.724968  1.061486  0.396360  1.578712
# 19  0.834861  0.836961  0.814629  1.042600  0.315742
# 20  0.090583  1.178913  0.666514  0.896119  0.461470
# 21  0.255593  0.753340  0.419657  0.267112  0.315742
# 22  1.302198  0.142604  0.172800  1.042600  1.262970
# 23  1.994550  1.016150  0.320914  0.120631  0.315742
# 24  1.077184  1.643311  1.061486  1.042600  1.651576
# 25  0.367523  1.156515  2.394514  0.508375  1.408697
# 26  0.134432  0.529354  1.653943  0.267112  1.190106
# 27  0.549843  0.187402  0.172800  0.120631  0.607197
# 28  0.661773  0.299395  1.308343  0.267112  0.170015
# 29  0.844092  2.427263  1.802057  0.913352  0.048576

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
#Now removing the data above Z score and creating a new df

df1=df[(z<3).all(axis=1)]  
df1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 3.3333333333333335

# %% [markdown]
# ### IQR Method

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2=df[~((df < (Q1-1.5*IQR))|(df> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0   95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2   81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3   76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4   74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6   87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7   81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8   80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9   78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 11  86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12  85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13  76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 19  64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20  90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21  83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22  71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23  67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92

# %%
print("Data Loss Percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 33.33333333333333

# %% [markdown]
# WE can see thet the loss of data is more in IQR method so we will use Zscore method

# %%
df=df1

# %% [markdown]
# ## Skewness

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
# now we will be removing skewness from CG,SV,E,SHO,H

# %%
import scipy.stats as stats
import numpy as np

# %%
df['CG'],ambda_=stats.yeojohnson(df['CG']) 
df['SV'],ambda_=stats.yeojohnson(df['SV']) 
df['E'],ambda_=stats.yeojohnson(df['E']) 
df['SHO'],ambda_=stats.yeojohnson(df['SHO']) 
df['H']=np.sin(df['H'])

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.292037
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %%
plt.figure(figsize=(30,35))
p=1
for i in df.columns:
    if p<=20:
        plt.subplot(10,5,p)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=10)
    p+=1
plt.show()

# %%
#Now we will check correlation with feature variables

df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780  0.116902  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.185803  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000 -0.039662  0.490752  0.445604 -0.064653
# H    0.116902  0.185803 -0.039662  1.000000  0.128112 -0.000263  0.293689
# 2B   0.384886  0.469293  0.490752  0.128112  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604 -0.000263  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653  0.293689 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850  0.088955  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.019898 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674 -0.089252  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499 -0.067276 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146 -0.007350 -0.224993  0.333731 -0.062094
# ERA -0.826952 -0.009122  0.254872  0.001481 -0.248212  0.325883 -0.070756
# CG   0.007696  0.155122 -0.059648  0.157420  0.227220 -0.004496  0.118284
# SHO  0.481626 -0.113640 -0.194219 -0.019244  0.088226 -0.066384 -0.024448
# SV   0.756713  0.083261 -0.147964  0.175828  0.241326 -0.269255  0.106523
# E   -0.079633  0.039865  0.332002 -0.291941  0.152541  0.080498 -0.165883
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.447513  0.156469 -0.169503 -0.823176 -0.815308 -0.826952  0.007696
# R    0.258450  0.081158  0.075323 -0.013858  0.007727 -0.009122  0.155122
# AB  -0.137850 -0.111243  0.373674  0.315499  0.309146  0.254872 -0.059648
# H    0.088955 -0.019898 -0.089252 -0.067276 -0.007350  0.001481  0.157420
# 2B   0.211243 -0.096772  0.194308 -0.215196 -0.224993 -0.248212  0.227220
# 3B  -0.404852 -0.196586  0.483818  0.312750  0.333731  0.325883 -0.004496
# HR   0.336814  0.479914 -0.166072 -0.092586 -0.062094 -0.070756  0.118284
# BB   1.000000  0.315566 -0.117622 -0.425381 -0.455832 -0.465794  0.445335
# SO   0.315566  1.000000  0.038188 -0.140570 -0.177655 -0.195362 -0.063129
# SB  -0.117622  0.038188  1.000000  0.134315  0.146243  0.128848 -0.040524
# RA  -0.425381 -0.140570  0.134315  1.000000  0.991286  0.986781  0.062434
# ER  -0.455832 -0.177655  0.146243  0.991286  1.000000  0.997261  0.067069
# ERA -0.465794 -0.195362  0.128848  0.986781  0.997261  1.000000  0.073959
# CG   0.445335 -0.063129 -0.040524  0.062434  0.067069  0.073959  1.000000
# SHO  0.441043  0.204704 -0.100054 -0.642749 -0.640161 -0.640503  0.208515
# SV   0.207948  0.125572 -0.195772 -0.625996 -0.604541 -0.619790 -0.302413
# E   -0.056106  0.164817  0.070527  0.231036  0.165556  0.138692 -0.070484
#
#           SHO        SV         E
# W    0.481626  0.756713 -0.079633
# R   -0.113640  0.083261  0.039865
# AB  -0.194219 -0.147964  0.332002
# H   -0.019244  0.175828 -0.291941
# 2B   0.088226  0.241326  0.152541
# 3B  -0.066384 -0.269255  0.080498
# HR  -0.024448  0.106523 -0.165883
# BB   0.441043  0.207948 -0.056106
# SO   0.204704  0.125572  0.164817
# SB  -0.100054 -0.195772  0.070527
# RA  -0.642749 -0.625996  0.231036
# ER  -0.640161 -0.604541  0.165556
# ERA -0.640503 -0.619790  0.138692
# CG   0.208515 -0.302413 -0.070484
# SHO  1.000000  0.196672 -0.206739
# SV   0.196672  1.000000 -0.032529
# E   -0.206739 -0.032529  1.000000

# %%
#Visualizing it on the heatmap

plt.figure(figsize=(45,45))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel("Figure")
plt.ylabel("Features name")
plt.title("Descriptive Graph")
plt.show()

# %%
#Checking the correlation of target variable only

df.corr()['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.756713
# SHO    0.481626
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# SO     0.156469
# H      0.116902
# CG     0.007696
# E     -0.079633
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='y')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# ## Seperating Features and Label

# %%
x=df.drop(['W'],axis=1)
y=df["W"]

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (29, 16)
# Target dimensions: (29,)

# %% [markdown]
# ## Feature scaling using standard scalarisation

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0
statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#      VIF values Features
# 0      6.967554        R
# 1     12.196315       AB
# 2      1.730291        H
# 3      3.569914       2B
# 4      3.289223       3B
# 5      8.057254       HR
# 6      3.375379       BB
# 7      2.802895       SO
# 8      1.798804       SB
# 9    203.839056       RA
# 10  2016.601245       ER
# 11  1540.326870      ERA
# 12     2.613004       CG
# 13     3.200985      SHO
# 14     5.418434       SV
# 15     1.794313        E

# %% [markdown]
# VIF = 1: Indicates no multicollinearity. The predictor variable is not correlated with other variables in the model. VIF > 1 and VIF < 5: Suggests moderate multicollinearity. The predictor variable is moderately correlated with other variables. VIF >= 5: Indicates high multicollinearity. The predictor variable is highly correlated with other variables, and its coefficient estimates may be unreliable

# %%
# removing the ER
x = x.drop("ER", axis=1)

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0     4.750206        R
# 1     3.441977       AB
# 2     1.647681        H
# 3     3.331922       2B
# 4     3.109929       3B
# 5     5.335086       HR
# 6     3.335042       BB
# 7     2.770763       SO
# 8     1.729929       SB
# 9   143.717888       RA
# 10  138.715007      ERA
# 11    2.363073       CG
# 12    3.141264      SHO
# 13    2.491945       SV
# 14    1.788176        E

# %%
# removing the ER
x = x.drop("RA", axis=1)

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0     4.452225        R
# 1     2.476968       AB
# 2     1.407843        H
# 3     3.278733       2B
# 4     3.096353       3B
# 5     5.226100       HR
# 6     2.730102       BB
# 7     2.257472       SO
# 8     1.573613       SB
# 9     4.382632      ERA
# 10    2.327516       CG
# 11    2.867767      SHO
# 12    2.359045       SV
# 13    1.581601        E

# %% [markdown]
# ## Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.9777054979461296 on random state 47

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: -0.08127169593287409
# R2 score on training data: 94.26130718141314
# Mean Absolute Error: 10.977084055288506
# Mean Squared Error: 145.85153765138992
# Root Mean Squared Error: 12.07690099534603

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.4316859967051073
# R2 score on training data: 91.50341212121214
# Mean Absolute Error: 7.293333333333332
# Mean Squared Error: 76.65924444444441
# Root Mean Squared Error: 8.75552650869406

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.22892915980230633
# R2 score on training data: 66.37575757575756
# Mean Absolute Error: 8.355555555555556
# Mean Squared Error: 104.0088888888889
# Root Mean Squared Error: 10.198474831507351

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.4863517378750888
# R2 score on training data: 99.99999757307519
# Mean Absolute Error: 6.91124947666649
# Mean Squared Error: 69.28544335773803
# Root Mean Squared Error: 8.323787801099812

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.6296615958792868
# R2 score on training data: 86.55418493693648
# Mean Absolute Error: 5.679068309277501
# Mean Squared Error: 49.9545358447273
# Root Mean Squared Error: 7.067852279492498

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.46946168654396103
# R2 score on training data: 93.50867525091114
# Mean Absolute Error: 7.473872101970508
# Mean Squared Error: 71.56372361507015
# Root Mean Squared Error: 8.459534479808575

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: -0.07550051967465521
# R2 score on training data: 23.756871571151983
# Mean Absolute Error: 10.397796610718048
# Mean Squared Error: 145.07307009833684
# Root Mean Squared Error: 12.044628267337139

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.41940428336079105
# R2 score on training data: 100.0
# Mean Absolute Error: 7.413333333333333
# Mean Squared Error: 78.31591111111108
# Root Mean Squared Error: 8.849627738561159

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.52987177 -1.40640289  0.67077905  0.67047967  0.61920659]
# 0.21678683801947582
# Difference between R2 score and CVS is: -29.805853395234994

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [ 0.4073033  -5.11213289  0.35130481  0.3275359   0.75994281]
# -0.6532092162672252
# Difference between R2 score and CVS is: 108.48952129723327

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-0.15268182 -2.26736842  0.31626934  0.18577049  0.57228774]
# -0.26914453364222785
# Difference between R2 score and CVS is: 49.80736934445342

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-0.01412286 -8.29209026  0.42217936  0.49882935  0.79542986]
# -1.3179549091640477
# Difference between R2 score and CVS is: 180.43066470391364

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.74994434 -0.5966751   0.78973013  0.7816987   0.88079107]
# 0.5210978288478024
# Difference between R2 score and CVS is: 10.85637670314844

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [ 0.41283247 -1.27700977  0.70437415  0.90072263  0.73674873]
# 0.2955336434675903
# Difference between R2 score and CVS is: 17.39280430763707

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-0.10801945 -1.26334869 -0.02464144 -0.49194475  0.12427025]
# -0.35273681713564503
# Difference between R2 score and CVS is: 27.723629746098982

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [ 0.06047943 -3.61591053  0.47627152  0.38987951  0.84620489]
# -0.3686150348479466
# Difference between R2 score and CVS is: 78.80193182087376

# %%
# We will take Lass as it has leat difference

# %% [markdown]
# ## HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[0.01, 0.1, 1.0, 10.0],
             'fit_intercept':[True,False],
             'normalize':[True,False],
             'precompute':[True,False],
             'selection':['cyclic', 'random']}

# %%
gscv=GridSearchCV(Lasso(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.0],
#                          'fit_intercept': [True, False],
#                          'normalize': [True, False],
#                          'precompute': [True, False],
#                          'selection': ['cyclic', 'random']})

# %%
 gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'normalize': False,
#  'precompute': True,
#  'selection': 'random'}

# %%
Model=Lasso(alpha= 1.0,
fit_intercept=True,
normalize=False,
precompute=True,
selection='random')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.6297659902259692
# Mean Absolute Error: 5.677972636860101
# Mean Squared Error: 49.94045420729704
# Root Mean Squared Error: 7.066856034142555

# %%
import pickle
filename='Baseball Case Study.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Baseball Case Study.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 62.97659902259692

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   
conclusion
# Out:
#                     0          1          2          3          4         5  \
# Predicted   91.383221  72.113458  73.653369  86.417703  80.453467  72.88037
# original   100.000000  76.000000  74.000000  86.000000  76.000000  64.00000
#
#                    6          7          8
# Predicted  82.447994  85.037591  88.014153
# original   95.000000  87.000000  98.000000
